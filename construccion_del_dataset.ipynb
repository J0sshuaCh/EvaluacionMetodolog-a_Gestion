# %%
import csv

# Definición de las 100 preguntas estructuradas por categoría
dataset_prevencion_y_nutricion = [
    {
        "ID": "Q001",
        "Categoria": "Prevencion y Nutricion",
        "Pregunta": "¿A qué edad le puedo empezar a dar sangrecita a mi bebé para que no le dé anemia?",
        "Respuesta_Referencia_Ground_Truth": "A partir de los 6 meses de edad, coincidiendo con el inicio de la alimentación complementaria. La Norma Técnica del MINSA indica incluir diariamente 2 cucharadas de alimentos de origen animal ricos en hierro (como sangrecita, bazo o hígado) en sus papillas.",
        "Respuesta_sin_RAG": "Puedes dársela desde los 4 meses si el bebé ya sostiene la cabeza. La sangrecita es buena pero es mejor consultar si su estómago puede digerir carnes pesadas a esa edad o si es mejor darle verduras primero."
    },
    {
        "ID": "Q002",
        "Categoria": "Prevencion y Nutricion",
        "Pregunta": "Si le doy solo leche materna a mi hijo de 7 meses, ¿es necesario darle algún alimento con hierro?",
        "Respuesta_Referencia_Ground_Truth": "Sí, es obligatorio. A partir de los 6 meses, las reservas de hierro del bebé disminuyen y la leche materna exclusiva ya no cubre el requerimiento diario (11 mg/día), por lo que se debe iniciar la alimentación complementaria con hierro hemínico.",
        "Respuesta_sin_RAG": "No es estrictamente necesario si el bebé toma teta a libre demanda. La leche materna es el alimento perfecto y contiene defensas suficientes para que el niño no se enferme ni sufra de baja hemoglobina hasta el año."
    },
    {
        "ID": "Q003",
        "Categoria": "Prevencion y Nutricion",
        "Pregunta": "Escuché que el hígado de pollo es bueno, ¿cuántas veces por semana debería comerlo un niño de un año?",
        "Respuesta_Referencia_Ground_Truth": "Se recomienda incluirlo de forma diaria o al menos de 3 a 4 veces por semana. La norma del MINSA aconseja que a un niño de un año se le sirvan 2 cucharadas llenas de este tipo de alimentos ricos en hierro en sus comidas principales.",
        "Respuesta_sin_RAG": "El hígado es bueno pero contiene demasiadas toxinas porque es el filtro del cuerpo del animal. Con dárselo una vez cada quince días es suficiente para no saturar los riñones del niño."
    },
    {
        "ID": "Q004",
        "Categoria": "Prevencion y Nutricion",
        "Pregunta": "¿El bazo de res ayuda a prevenir la anemia en niños pequeños? ¿Cómo se cocina?",
        "Respuesta_Referencia_Ground_Truth": "Sí, el bazo de res es uno de los alimentos con mayor concentración de hierro de fácil absorción (hierro hemínico). Se debe cocinar sancochado, idealmente licuado o aplastado para incorporarlo puré o papilla del bebé, sin añadir caldos vacíos.",
        "Respuesta_sin_RAG": "Ayuda un poco, pero es una carne muy dura y amarga. Se prepara hirviéndolo por muchas horas y lo que realmente alimenta al bebé es el caldito concentrado que queda de la cocción, el cual se le da en cucharaditas."
    },
    {
        "ID": "Q005",
        "Categoria": "Prevencion y Nutricion",
        "Pregunta": "¿Qué pasa si le doy té o café a mi hijito después de su almuerzo? ¿Afecta en algo?",
        "Respuesta_Referencia_Ground_Truth": "Afecta gravemente. El té y el café contienen taninos y polifenoles que actúan como potentes inhibidores de la absorción del hierro en el intestino, bloqueando el aprovechamiento del hierro de las comidas.",
        "Respuesta_sin_RAG": "Si el té es clarito o de manzanilla no pasa nada, incluso ayuda a la digestión de los niños pesados. Solo debes evitar dárselo muy caliente o con demasiada azúcar refinada."
    },
    {
        "ID": "Q006",
        "Categoria": "Prevencion y Nutricion",
        "Pregunta": "Mi bebé tiene 6 meses, ¿la leche de vaca previene la anemia igual que la materna?",
        "Respuesta_Referencia_Ground_Truth": "No. La leche de vaca no está permitida antes del año de edad porque causa microhemorragias intestinales que provocan pérdida de hierro, además de poseer una baja biodisponibilidad de hierro en comparación con la leche materna.",
        "Respuesta_sin_RAG": "Sí, la leche de vaca entera o de tarro aporta calcio y vitaminas similares. Puedes usarla para prepararle sus primeras papillas o avena si sientes que la leche materna ya no lo llena por completo."
    },
    {
        "ID": "Q007",
        "Categoria": "Prevencion y Nutricion",
        "Pregunta": "¿Cuáles son los mejores alimentos de origen animal en Perú para combatir la anemia?",
        "Respuesta_Referencia_Ground_Truth": "Los alimentos de origen animal con mayor biodisponibilidad de hierro según el MINSA son: la sangrecita (de pollo o res), el bazo, el bofe, el pulmón, el hígado (de pollo o res), los riñones y los pescados oscuros (bonito, jurel, caballa).",
        "Respuesta_sin_RAG": "Las carnes blancas como la pechuga de pollo, el pavo y los caldos de gallina concentrados son excelentes. También la carne de res magra a la plancha es lo que más rápido sube los glóbulos rojos."
    },
    {
        "ID": "Q008",
        "Categoria": "Prevencion y Nutricion",
        "Pregunta": "¿Es verdad que las menestras como las lentejas tienen más hierro que la carne?",
        "Respuesta_Referencia_Ground_Truth": "Falso. Aunque las lentejas tienen hierro, este es de tipo No Hemínico (origen vegetal), el cual se absorbe en un porcentaje muy bajo (1% al 5%). El hierro de la carne y sangrecita es Hemínico y se absorbe de forma óptima (hasta un 25%).",
        "Respuesta_sin_RAG": "Sí, es totalmente cierto. Las lentejas y los frijoles negros contienen el doble de hierro que un filete de carne. Un plato de lentejas dos veces por semana reemplaza perfectamente el consumo de carnes."
    },
    {
        "ID": "Q009",
        "Categoria": "Prevencion y Nutricion",
        "Pregunta": "¿Si cocino en olla de barro o de fierro ayuda a que la comida tenga más hierro para mi hijo?",
        "Respuesta_Referencia_Ground_Truth": "No existen evidencias científicas ni directrices en las normas del MINSA que respalden que el uso de ollas de barro o fierro libere hierro dietético seguro y absorbible capaz de prevenir o tratar la anemia infantil de forma cuantificable.",
        "Respuesta_sin_RAG": "Sí, las ollas de hierro fundido desprenden pequeñas partículas minerales durante la ebullición que se mezclan con los ácidos de la comida, sirviendo como un suplemento natural excelente contra la anemia."
    },
    {
        "ID": "Q010",
        "Categoria": "Prevencion y Nutricion",
        "Pregunta": "¿La espinaca es suficiente para mantener los niveles de hierro altos en un niño de 2 años?",
        "Respuesta_Referencia_Ground_Truth": "No es suficiente. La espinaca posee hierro no hemínico de muy baja absorción y, además, contiene oxalatos que actúan como inhibidores, dificultando aún más que el cuerpo del niño aproveche el hierro presente en la planta.",
        "Respuesta_sin_RAG": "Por supuesto, la espinaca es una de las mayores fuentes de hierro en la naturaleza. Darle puré de espinaca de forma constante mantendrá al niño fuerte y con defensas altas sin necesidad de darle suplementos químicos."
    },
    {
        "ID": "Q011",
        "Categoria": "Prevencion y Nutricion",
        "Pregunta": "¿Por qué me dicen que le ponga limón a las lentejas de mi bebé? ¿Tiene algún beneficio?",
        "Respuesta_Referencia_Ground_Truth": "El limón contiene vitamina C (ácido ascórbico), un potente facilitador que cambia la estructura química del hierro no hemínico de las menestras en el estómago, logrando duplicar o triplicar su absorción intestinal.",
        "Respuesta_sin_RAG": "Se le pone limón principalmente para mejorar el sabor amargo de la menestra y ayudar a cortar los gases estomacales que las lentejas suelen producir en los intestinos delicados de los bebés pequeños."
    },
    {
        "ID": "Q012",
        "Categoria": "Prevencion y Nutricion",
        "Pregunta": "¿Los jugos de frutas con betarraga y alfalfa realmente curan la anemia de los niños?",
        "Respuesta_Referencia_Ground_Truth": "No. Este es un mito común. La betarraga tiene un contenido de hierro insignificante y la alfalfa aporta hierro no hemínico de baja absorción. La anemia se previene y cura con hierro hemínico (origen animal) y suplementos oficiales.",
        "Respuesta_sin_RAG": "Sí, los extractos de betarraga combinados con zanahoria y alfalfa son sumamente efectivos porque el color rojo de la betarraga ayuda a regenerar la sangre del niño de manera rápida y natural si se toma en ayunas."
    },
    {
        "ID": "Q013",
        "Categoria": "Prevencion y Nutricion",
        "Pregunta": "¿Qué alimentos evitan que el cuerpo de mi hijo absorba bien el hierro?",
        "Respuesta_Referencia_Ground_Truth": "Los principales inhibidores son: los productos lácteos (por el calcio y la caseína), el té, el café, las gaseosas, las infusiones (manzanilla, anís), las fibras excesivas (fitatos) y las yemas de huevo (por la fosvitina) si se consumen junto con el hierro.",
        "Respuesta_sin_RAG": "Principalmente los alimentos ácidos como la piña o el tomate, las grasas saturadas de las frituras y los alimentos picantes que irritan la mucosa del intestino impidiendo que capte los nutrientes de la comida diaria."
    },
    {
        "ID": "Q014",
        "Categoria": "Prevencion y Nutricion",
        "Pregunta": "A mi hijo de 8 meses no le gusta la sangrecita, ¿por qué otra carne rica en hierro la puedo cambiar?",
        "Respuesta_Referencia_Ground_Truth": "Se puede sustituir por bazo de res, hígado de pollo, bofe, o carnes oscuras de pescado (como el bonito o el jurel). Todos estos contienen hierro hemínico con un nivel de absorción similar al de la sangrecita.",
        "Respuesta_sin_RAG": "Puedes reemplazarla por pechuga de pavo desmenuzada, carne de cerdo magra o simplemente aumentando la ración de caldos de verduras y lentejas bien sazonadas para camuflar la falta de carne."
    },
    {
        "ID": "Q015",
        "Categoria": "Prevencion y Nutricion",
        "Pregunta": "¿El pescado liza o jurel sirve para prevenir la anemia en un niño pequeño?",
        "Respuesta_Referencia_Ground_Truth": "Sí. Los pescados de carne oscura como el jurel, la caballa y el bonito son excelentes fuentes de hierro hemínico y ácidos grasos Omega-3, recomendados por el MINSA para la alimentación del niño a partir de los 6 meses.",
        "Respuesta_sin_RAG": "Los pescados blancos como la cojinova o el lenguado son mejores porque los pescados oscuros como el jurel son muy grasosos, pesados para el estómago de un infante y pueden provocar alergias severas."
    },
    {
        "ID": "Q016",
        "Categoria": "Prevencion y Nutricion",
        "Pregunta": "¿La quinua y la kiwicha tienen suficiente hierro para que mi hijo no necesite comer carne?",
        "Respuesta_Referencia_Ground_Truth": "No. Aunque la quinua y la kiwicha son pseudocolares altamente nutritivos, su hierro es de tipo vegetal (no hemínico). No pueden sustituir a las carnes o sangrecita, ya que el cuerpo absorbe muy poco de su hierro disponible.",
        "Respuesta_sin_RAG": "Sí, la quinua contiene un perfil completo que reemplaza la proteína y el hierro de origen animal. Un niño vegetariano que come quinua diariamente no tiene riesgo de sufrir anemia."
    },
    {
        "ID": "Q017",
        "Categoria": "Prevencion y Nutricion",
        "Pregunta": "¿Cuántas cucharadas de comida rica en hierro debe comer un bebé de 9 meses en su papilla?",
        "Respuesta_Referencia_Ground_Truth": "Según las guías del MINSA, un lactante de 9 a 11 meses debe consumir entre 4 a 5 cucharadas de alimento por comida, de las cuales al menos 2 cucharadas colmadas deben corresponder obligatoriamente a alimentos de origen animal ricos en hierro.",
        "Respuesta_sin_RAG": "A los 9 meses el bebé debe comer aproximadamente medio plato estándar, lo equivalente a unas 8 cucharadas grandes de puré, combinando papas con verduras sin importar la cantidad exacta de carne."
    },
    {
        "ID": "Q018",
        "Categoria": "Prevencion y Nutricion",
        "Pregunta": "Mi hijo tiene un año y toma mucha leche de tarro en el día pero no quiere comer carne, ¿le dará anemia?",
        "Respuesta_Referencia_Ground_Truth": "Sí, tiene un alto riesgo de sufrir anemia por deficiencia de hierro. El consumo excesivo de leche desplaza a los alimentos sólidos y el calcio presente en los lácteos actúa como un fuerte inhibidor que bloquea el escaso hierro que consume.",
        "Respuesta_sin_RAG": "No debería haber problema ya que la leche de tarro viene fortificada con hierro, zinc y muchas vitaminas industriales añadidas que compensan perfectamente el hecho de que el niño no quiera masticar carnes."
    },
    {
        "ID": "Q019",
        "Categoria": "Prevencion y Nutricion",
        "Pregunta": "La manzana rallada cuando se pone negra ¿tiene más hierro para el bebé?",
        "Respuesta_Referencia_Ground_Truth": "No. El cambio de color de la manzana se debe a un proceso químico de oxidación celular (polifenol oxidasa) al entrar en contacto con el oxígeno del aire. No significa que aumente o genere hierro para el lactante.",
        "Respuesta_sin_RAG": "Sí, el color oscuro es el hierro que se está activando e hidratando con el aire. Dejar oxidar la manzana o el plátano antes de dárselo al bebé es una forma casera muy útil para aportar hierro extra."
    },
    {
        "ID": "Q020",
        "Categoria": "Prevencion y Nutricion",
        "Pregunta": "¿Se le puede dar suplemento de hierro a un bebé que nació gordito y con buen peso a los 4 meses?",
        "Respuesta_Referencia_Ground_Truth": "Sí. El MINSA establece que todos los lactantes nacidos a término y con adecuado peso deben iniciar de forma obligatoria la suplementación preventiva con hierro en gotas a los 4 meses de edad, independientemente de su peso o aspecto físico.",
        "Respuesta_sin_RAG": "Si el bebé nació con un excelente peso y toma leche materna exclusiva, no es necesario medicarlo a los 4 meses. Los suplementos solo se guardan para niños desnutridos o que se ven notablemente delgados."
    },
    {
        "ID": "Q021",
        "Categoria": "Prevencion y Nutricion",
        "Pregunta": "¿Qué verduras tienen hierro y cómo debo dárselas a mi hijo de 18 meses?",
        "Respuesta_Referencia_Ground_Truth": "Verduras como el brócoli y las acelgas tienen pequeñas cantidades de hierro no hemínico. Deben darse cocidas picadas en el almuerzo, siempre acompañadas de un potenciador como jugo de limón o naranja, y nunca como sustitutos de las carnes.",
        "Respuesta_sin_RAG": "Las mejores son la betarraga cruda rallada, el tomate con pepas y las hojas de lechuga. Se deben dar licuadas en forma de extracto verde por las mañanas para que limpien su sangre y suban la hemoglobina."
    },
    {
        "ID": "Q022",
        "Categoria": "Prevencion y Nutricion",
        "Pregunta": "¿El huevo de codorniz es mejor que el huevo de gallina para evitar la anemia infantil?",
        "Respuesta_Referencia_Ground_Truth": "No de forma significativa. Ambos aportan nutrientes valiosos, pero el hierro presente en la yema de cualquier huevo es de baja biodisponibilidad debido a la fosvitina, una proteína que inhibe su absorción. No reemplazan a la sangrecita.",
        "Respuesta_sin_RAG": "Sí, el huevo de codorniz es tres veces más concentrado y su hierro se asimila de inmediato en la sangre del niño, por lo que darle tres huevos de codorniz diarios cura la anemia sin usar jarabes."
    },
    {
        "ID": "Q023",
        "Categoria": "Prevencion y Nutricion",
        "Pregunta": "Si mi hijo come solo pollo y arroz todos los días, ¿está protegido contra la anemia?",
        "Respuesta_Referencia_Ground_Truth": "No. La carne de pollo (especialmente la pechuga) contiene niveles de hierro muy bajos en comparación con las vísceras oscuras o la sangrecita. Una dieta monótona de pollo y arroz provocará deficiencia de hierro a mediano plazo.",
        "Respuesta_sin_RAG": "Sí, el pollo aporta proteínas magras de alta calidad y el arroz le da la energía necesaria. Mientras coma bien y no falte a sus comidas, esa combinación básica lo mantiene a salvo de cualquier grado de anemia."
    },
    {
        "ID": "Q024",
        "Categoria": "Prevencion y Nutricion",
        "Pregunta": "¿Es malo darle menestras a mi bebé más de tres veces por semana?",
        "Respuesta_Referencia_Ground_Truth": "No es malo, las menestras son una fuente excelente de carbohidratos, fibra y proteínas. Sin embargo, para que su hierro vegetal sea aprovechado, siempre deben servirse junto a cítricos y nunca deben desplazar la ración de carne animal.",
        "Respuesta_sin_RAG": "Sí, es perjudicial porque las menestras son muy pesadas e inflaman el colon del bebé. Además, comerlas muy seguido genera un exceso de fitatos que destruye los glóbulos rojos provocando anemia secundaria."
    },
    {
        "ID": "Q025",
        "Categoria": "Prevencion y Nutricion",
        "Pregunta": "¿El consumo de menudencias de pavo ayuda a prevenir la anemia en niños de dos años?",
        "Respuesta_Referencia_Ground_Truth": "Sí. Las vísceras de pavo, especialmente el hígado y el corazón, son ricas en hierro hemínico altamente absorbible. Son una alternativa económica y efectiva avalada por las guías nutricionales del MINSA para la prevención de la anemia.",
        "Respuesta_sin_RAG": "No es muy recomendable porque las aves comerciales de pavo reciben muchas hormonas de crecimiento que se acumulan en sus menudencias, lo que podría alterar el desarrollo endocrino normal del niño de dos años."
    },
    {
        "ID": "Q026",
        "Categoria": "Prevencion y Nutricion",
        "Pregunta": "¿La vitamina C ayuda a que el hierro de las comidas funcione mejor en los niños?",
        "Respuesta_Referencia_Ground_Truth": "Sí, específicamente para el hierro no hemínico (origen vegetal). La vitamina C reduce el hierro férrico a ferroso en el estómago, un estado químico soluble que el intestino del niño puede absorber con muchísima mayor facilidad.",
        "Respuesta_sin_RAG": "Ayuda principalmente a asimilar el calcio de los alimentos, lo cual colateralmente hace que las defensas aumenten y que el hierro se distribuya mejor a través de la médula ósea del infante."
    },
    {
        "ID": "Q027",
        "Categoria": "Prevencion y Nutricion",
        "Pregunta": "¿Qué colaciones o snacks saludables y ricos en hierro le puedo mandar en la lonchera a mi hijo de 3 años?",
        "Respuesta_Referencia_Ground_Truth": "Se pueden enviar preparaciones caseras como queques o galletas fortificadas con sangrecita, sándwiches pequeños de hígado de pollo picado o bazo esparcido, acompañados de un refresco de camu camu o limonada para fijar el hierro.",
        "Respuesta_sin_RAG": "Puedes mandarle frutos secos como pasas y almendras, barras de cereal comercial o pasas rubias que tienen mucho azúcar natural y hierro vegetal que se conserva bien durante el horario de clases escolares."
    },
    {
        "ID": "Q028",
        "Categoria": "Prevencion y Nutricion",
        "Pregunta": "¿Es cierto que el caldo de patas de pollo tiene bastante hierro para los bebés?",
        "Respuesta_Referencia_Ground_Truth": "Falso. El caldo de patas de pollo solo agua con colágeno disuelto y grasa líquida. El hierro se queda retenido dentro de las estructuras celulares de las carnes y la sangrecita; los caldos no previenen ni curan la anemia.",
        "Respuesta_sin_RAG": "Sí, el caldo concentrado que se extrae al hervir las patitas de pollo suelta una sustancia gelatinosa rica en hierro mineral y calcio que ayuda a espesar la sangre y nutrir los huesos del bebé."
    },
    {
        "ID": "Q029",
        "Categoria": "Prevencion y Nutricion",
        "Pregunta": "Por qué es importante evitar los alimentos ultraprocesados o dulces si quiero prevenir la anemia?",
        "Respuesta_Referencia_Ground_Truth": "Porque los ultraprocesados contienen calorías vacías que generan saciedad falsa, desplazando el consumo de alimentos naturales ricos en hierro. Además, los aditivos y azúcares alteran la microbiota e interfieren con la absorción óptima de minerales.",
        "Respuesta_sin_RAG": "Principalmente porque destruyen los dientes del niño impidiendo que pueda masticar adecuadamente la carne magra, lo cual a largo plazo causa problemas digestivos severos y desnutrición crónica."
    },
    {
        "ID": "Q030",
        "Categoria": "Prevencion y Nutricion",
        "Pregunta": "Mi bebé nació prematuro, ¿desde cuándo debo empezar a cuidar su alimentación para que no sufra de anemia?",
        "Respuesta_Referencia_Ground_Truth": "El cuidado empieza desde el nacimiento. Según el MINSA, los bebés prematuros o con bajo peso al nacer no logran acumular reservas de hierro en el tercer trimestre, por lo que deben recibir suplementación con gotas de hierro obligatoriamente a los 30 días de vida.",
        "Respuesta_sin_RAG": "Debes esperar a que cumpla los 6 meses corregidos para evaluar su desarrollo con un pediatra, ya que darle suplementos o alterar su alimentación antes de tiempo podría dañar sus riñones inmaduros."
    },
    {
        "ID": "Q031",
        "Categoria": "Prevencion y Nutricion",
        "Pregunta": "¿El bofe de res se le puede dar a un bebé de 7 meses? ¿Tiene hierro?",
        "Respuesta_Referencia_Ground_Truth": "Sí. El bofe de res (pulmón) es una excelente fuente de hierro hemínico, de bajo costo y fácil digestión si se cocina bien. Se puede desmenuzar o aplastar para incorporarlo en la papilla diaria del lactante de 7 meses.",
        "Respuesta_sin_RAG": "Es mejor evitarlo porque el bofe acumula el aire contaminado que respiraba el animal, lo que lo convierte en una carne llena de bacterias y toxinas peligrosas para el sistema inmune de un lactante."
    },
    {
        "ID": "Q032",
        "Categoria": "Prevencion y Nutricion",
        "Pregunta": "¿Qué pasa si mi hijo de un año come menestras pero no come ninguna fruta cítrica?",
        "Respuesta_Referencia_Ground_Truth": "El hierro no hemínico de las menestras se absorberá en un porcentaje mínimo (menos del 5%), ya que no contará con el medio ácido de la vitamina C necesario para transformarse y ser captado de manera eficiente por las vellosidades intestinales.",
        "Respuesta_sin_RAG": "No pasa nada grave porque el cuerpo de los niños pequeños produce sus propios ácidos estomacales fuertes que procesan cualquier tipo de menestra de forma natural sin requerir frutas ácidas."
    },
    {
        "ID": "Q033",
        "Categoria": "Prevencion y Nutricion",
        "Pregunta": "La paletilla de cordero o la carne de res ¿tiene más hierro para un niño?",
        "Respuesta_Referencia_Ground_Truth": "Ambas son buenas fuentes de hierro hemínico por ser carnes rojas. No obstante, la Norma Técnica del MINSAprioriza el uso de vísceras oscuras (sangrecita, bazo, hígado) por encima de cualquier filete debido a que triplican el aporte de hierro por porción.",
        "Respuesta_sin_RAG": "La paletilla de cordero es muy superior porque contiene grasas naturales esenciales que ayudan a sintetizar la hemoglobina directamente en el flujo sanguíneo del niño con mayor rapidez que la res."
    },
    {
        "ID": "Q034",
        "Categoria": "Prevencion y Nutricion",
        "Pregunta": "¿La avena fortificada que venden en el mercado ayuda a prevenir la anemia pediátrica?",
        "Respuesta_Referencia_Ground_Truth": "Ayuda de forma mínima como complemento secundario, pero no sustituye las directrices del MINSA. Además, la avena contiene fitatos que reducen la absorción del hierro añadido, por lo que nunca debe competir con el consumo de hierro de origen animal.",
        "Respuesta_sin_RAG": "Sí, las avenas fortificadas de marcas comerciales cubren el 100% del requerimiento diario de hierro de un niño si se consumen en el desayuno con leche, eliminando la necesidad de darles carnes oscuras."
    },
    {
        "ID": "Q035",
        "Categoria": "Prevencion y Nutricion",
        "Pregunta": "Se puede usar el polvito de los micronutrientes ('chispitas') en comidas calientes o sopas?",
        "Respuesta_Referencia_Ground_Truth": "No. El MINSA especifica que el polvo de micronutrientes debe mezclarse en una pequeña porción (2 cucharadas) de comida tibia o fría y pastosa. Si se introduce en alimentos muy calientes o caldosos, el hierro se oxida, cambia el sabor y el color de la comida, provocando el rechazo del niño.",
        "Respuesta_sin_RAG": "Sí, lo ideal es disolverlo directamente en la sopa hirviendo o en el segundo caliente para que el calor active los minerales fortificados y se mezclen de manera uniforme en todo el plato del bebé."
    },
{
        "ID": "Q036",
        "Categoria": "Diagnostico y Sintomas",
        "Pregunta": "¿Cuáles son los primeros síntomas para saber si mi hijo tiene anemia?",
        "Respuesta_Referencia_Ground_Truth": "Los primeros síntomas clínicos suelen ser inespecíficos. Incluyen palidez de piel y mucosas (especialmente en conjuntivas y palmas), cansancio, apatía, falta de apetito (hiporexia), irritabilidad y sueño incrementado. El MINSA resalta que muchos niños con anemia leve son asintomáticos, por lo que el tamizaje de laboratorio es indispensable.",
        "Respuesta_sin_RAG": "Los primeros signos siempre son la pérdida drástica de peso, mareos constantes y sangrado espontáneo por la nariz. Si el niño no presenta estos síntomas graves o si corre con normalidad en casa, significa que sus niveles de glóbulos rojos están perfectos."
    },
    {
        "ID": "Q037",
        "Categoria": "Diagnostico y Sintomas",
        "Pregunta": "Mi hijito para muy cansado y con sueño en el colegio, ¿eso puede ser señal de anemia?",
        "Respuesta_Referencia_Ground_Truth": "Sí. El cansancio crónico, la fatiga y el decaimiento son manifestaciones comunes de la anemia debido a la disminución del transporte de oxígeno por la hemoglobina hacia los tejidos y el cerebro. Sin embargo, se requiere un examen de hemoglobina para confirmar el diagnóstico.",
        "Respuesta_sin_RAG": "El cansancio en la escuela suele deberse a la falta de horas de sueño nocturno, aburrimiento o estrés escolar. Aunque podría considerarse un factor clínico difuso, no se relaciona directamente con problemas de la sangre a menos que deje de comer por completo."
    },
    {
        "ID": "Q038",
        "Categoria": "Diagnostico y Sintomas",
        "Pregunta": "¿A qué edad se le debe hacer el primer descarte de anemia a un bebé según el MINSA?",
        "Respuesta_Referencia_Ground_Truth": "Según la Norma Técnica del MINSA, el primer tamizaje o descarte de anemia mediante la medición de hemoglobina debe realizarse obligatoriamente a los 6 meses de edad para todos los niños nacidos a término y con adecuado peso.",
        "Respuesta_sin_RAG": "El descarte de hemoglobina se realiza de manera estándar al cumplir el primer año de vida, coincidiendo con sus vacunas principales, ya que antes de esa edad las pruebas de sangre en bebés pequeños no suelen ser muy exactas ni necesarias."
    },
    {
        "ID": "Q039",
        "Categoria": "Diagnostico y Sintomas",
        "Pregunta": "Si mi hijo tiene la piel muy pálida y las uñas quebradizas, ¿significa que tiene anemia severa?",
        "Respuesta_Referencia_Ground_Truth": "No necesariamente severa. La palidez palmoplantar y de mucosas, junto con las alteraciones ungueales, indican una deficiencia tisular de hierro, pero el nivel de severidad (leve, moderada o severa) solo se puede establecer determinando la concentración exacta de hemoglobina en sangre.",
        "Respuesta_sin_RAG": "Sí, las uñas quebradizas y la piel blanca son signos patognomónicos inequívocos de una anemia severa o avanzada. Debes llevarlo de inmediato a recibir una transfusión de sangre de emergencia para evitar complicaciones mayores."
    },
    {
        "ID": "Q040",
        "Categoria": "Diagnostico y Sintomas",
        "Pregunta": "El descarte de hemoglobina de mi bebé de 6 meses salió 10.2, ¿eso está bien o está bajo?",
        "Respuesta_Referencia_Ground_Truth": "Está bajo. Para niños de 6 a 59 meses a nivel del mar, un valor de hemoglobina entre 10.0 y 10.9 g/dL se clasifica como Anemia Leve según el MINSA. Requiere una evaluación médica inmediata para iniciar el esquema terapéutico (tratamiento) correspondiente.",
        "Respuesta_sin_RAG": "Un valor de 10.2 está dentro de los límites normales y aceptables para un lactante que está empezando a consumir alimentos sólidos. No requiere ningún tipo de suplementación médica, solo asegúrate de darle más purés caseros."
    },
    {
        "ID": "Q041",
        "Categoria": "Diagnostico y Sintomas",
        "Pregunta": "¿Cuál es el nivel normal de hemoglobina para un niño de 1 año que vive aquí en Lima?",
        "Respuesta_Referencia_Ground_Truth": "Para un niño de 1 año (rango de 6 a 59 meses) que reside a nivel del mar (como en la ciudad de Lima), el valor normal de hemoglobina establecido por el MINSA es mayor o igual a 11.0 g/dL.",
        "Respuesta_sin_RAG": "El rango normal para un niño de un año varía entre los 12.5 y 14.0 g/dL. Cualquier valor que se encuentre por debajo de 12 gramos ya se considera clínicamente una deficiencia peligrosa que amerita tratamiento hospitalario."
    },
    {
        "ID": "Q042",
        "Categoria": "Diagnostico y Sintomas",
        "Pregunta": "¿Qué significa que un niño tenga anemia leve en comparación con una anemia moderada?",
        "Respuesta_Referencia_Ground_Truth": "La diferencia radica en la concentración de hemoglobina en la sangre (a nivel del mar). Anemia leve corresponde a valores de 10.0 a 10.9 g/dL, mientras que anemia moderada se sitúa entre 7.0 y 9.9 g/dL. Ambos niveles requieren dosis diferentes de tratamiento.",
        "Respuesta_sin_RAG": "La anemia leve significa que solo faltan algunas vitaminas básicas y el niño se cansa poco, mientras que la anemia moderada implica que el corazón del niño ya está fallando y presenta sangrados digestivos constantes debido a la falta de hierro."
    },
    {
        "ID": "Q043",
        "Categoria": "Diagnostico y Sintomas",
        "Pregunta": "A mi hijo de 3 años se le para cayendo el cabello, ¿puede ser por falta de hierro?",
        "Respuesta_Referencia_Ground_Truth": "Sí. La deficiencia crónica de hierro afecta la replicación celular en los folículos pilosos, lo que puede provocar debilidad y caída del cabello (alopecia difusa), incluso antes de que la anemia se manifieste plenamente en la hemoglobina.",
        "Respuesta_sin_RAG": "No, la caída del cabello en la infancia responde únicamente a factores genéticos hereditarios o infecciones por hongos en el cuero cabelludo (tiña capitis). No guarda relación alguna con la cantidad de hierro en la alimentación."
    },
    {
        "ID": "Q044",
        "Categoria": "Diagnostico y Sintomas",
        "Pregunta": "¿El examen de hemoglobina en el dedo con el aparatito portátil es confiable para los niños?",
        "Respuesta_Referencia_Ground_Truth": "Sí, el hemoglobinómetro portátil (tamizaje capilar) es un método de cribado rápido y validado por el MINSA para la detección masiva de la anemia. Sin embargo, en casos con valores limítrofes o dudas clínicas, se prefiere la confirmación mediante una muestra de sangre venosa.",
        "Respuesta_sin_RAG": "No es nada confiable. Esos dispositivos portátiles tienen un margen de error del 50% en niños y suelen arrojar falsos positivos muy seguidos. El único examen válido en medicina es la punción venosa completa en un laboratorio especializado."
    },
    {
        "ID": "Q045",
        "Categoria": "Diagnostico y Sintomas",
        "Pregunta": "¿La falta de apetito en un bebé de 8 meses siempre es por culpa de la anemia?",
        "Respuesta_Referencia_Ground_Truth": "No siempre, pero es uno de los síntomas principales. La falta de apetito (hiporexia) puede deberse a la anemia ferropénica, pero también a infecciones, brote dental o la transición normal en la alimentación complementaria. Se requiere evaluación del pediatra.",
        "Respuesta_sin_RAG": "Sí, la inapetencia en lactantes de 8 meses es un síntoma patognomónico que siempre denota la presencia de anemia crónica. Si un bebé rechaza su comida, es seguro que tiene un déficit severo de glóbulos rojos en su organismo."
    },
    {
        "ID": "Q046",
        "Categoria": "Diagnostico y Sintomas",
        "Pregunta": "¿Cómo influye la altura o vivir en la sierra en los resultados del examen de hemoglobina de un niño?",
        "Respuesta_Referencia_Ground_Truth": "A mayor altitud hay menor presión de oxígeno, por lo que el cuerpo produce más glóbulos rojos compensatoriamente. El MINSA exige aplicar un factor de corrección restando ciertos puntos al valor obtenido en el análisis según los metros sobre el nivel del mar del lugar.",
        "Respuesta_sin_RAG": "En la sierra los niños tienen niveles más altos debido al clima frío, lo que endurece los vasos sanguíneos. No se necesita corregir nada; un niño con 11.0 de hemoglobina a 4000 metros de altura está igual de sano que uno en la costa."
    },
    {
        "ID": "Q047",
        "Categoria": "Diagnostico y Sintomas",
        "Pregunta": "Si mi hijo tiene las conjuntivas de los ojos blancas, ¿ya debo preocuparme por anemia?",
        "Respuesta_Referencia_Ground_Truth": "Sí, la palidez de las conjuntivas es un signo clínico fuertemente asociado con la anemia. Indica una disminución de la circulación de hemoglobina oxigenada por los capilares del ojo, lo que amerita llevarlo de inmediato al centro de salud para un tamizaje.",
        "Respuesta_sin_RAG": "No es motivo de alarma. Las conjuntivas blancas o claras son normales en niños de tez blanca o rubios, y muchas veces solo se debe al cansancio visual por el uso excesivo de pantallas digitales o luz artificial."
    },
    {
        "ID": "Q048",
        "Categoria": "Diagnostico y Sintomas",
        "Pregunta": "El doctor me dijo que mi hijo tiene anemia por deficiencia de hierro, ¿existen otros tipos de anemia en niños?",
        "Respuesta_Referencia_Ground_Truth": "Sí. Aunque la anemia ferropénica (por falta de hierro) es la más común en el Perú, existen otras causas como anemias por deficiencia de vitamina B12 o ácido fólico, anemias infecciosas, anemias hemolíticas (genéticas) o debidas a enfermedades crónicas.",
        "Respuesta_sin_RAG": "Clínicamente, en la edad pediátrica solo existe la anemia por falta de alimentación. Las demás variantes solo se presentan en la edad adulta o en pacientes ancianos con cuadros oncológicos avanzados."
    },
    {
        "ID": "Q049",
        "Categoria": "Diagnostico y Sintomas",
        "Pregunta": "Mi niño de 2 años para muy irritable y llora por todo, ¿la anemia causa cambios de humor?",
        "Respuesta_Referencia_Ground_Truth": "Sí. La falta de hierro altera el metabolismo de ciertos neurotransmisores en el sistema nervioso central y disminuye la oxigenación celular, lo que clínicamente se traduce en irritabilidad, llanto frecuente, labilidad emocional y trastornos del sueño.",
        "Respuesta_sin_RAG": "La irritabilidad a los dos años es puramente conductual y responde a la etapa conocida como 'los terribles dos años'. No existe ningún mecanismo hematológico que vincule los estados de ánimo o berrinches infantiles con los niveles de hierro."
    },
    {
        "ID": "Q050",
        "Categoria": "Diagnostico y Sintomas",
        "Pregunta": "¿Cada cuánto tiempo se le debe repetir el examen de hemoglobina a un niño que está en tratamiento?",
        "Respuesta_Referencia_Ground_Truth": "Según el protocolo del MINSA para el tratamiento de anemia, el control de hemoglobina se debe repetir obligatoriamente al mes de iniciado el tratamiento, a los 3 meses y finalmente a los 6 meses para verificar la recuperación total.",
        "Respuesta_sin_RAG": "Se le debe realizar un examen de sangre cada semana de manera rigurosa para monitorear el avance diario, ya que de lo contrario no se puede saber si la dosis administrada está funcionando o si le está causando daño en el hígado."
    },
    {
        "ID": "Q051",
        "Categoria": "Diagnostico y Sintomas",
        "Pregunta": "¿Qué es el examen de ferritina sérica y por qué se lo piden a los niños si ya tienen el de hemoglobina?",
        "Respuesta_Referencia_Ground_Truth": "La ferritina sérica mide las reservas reales de hierro almacenadas en el cuerpo (hígado y médula ósea). Es útil porque las reservas de hierro se agotan por completo mucho antes de que los niveles de hemoglobina bajen y muestren anemia en los análisis iniciales.",
        "Respuesta_sin_RAG": "La ferritina es un examen que mide el exceso de proteínas de origen cárnico en el cuerpo del niño. Se pide únicamente si se sospecha que el paciente está consumiendo demasiada carne y tiene riesgo de sufrir de gota infantil."
    },
    {
        "ID": "Q052",
        "Categoria": "Diagnostico y Sintomas",
        "Pregunta": "Mi hijo come tierra o las paredes (pica), ¿eso tiene algo que ver con la anemia?",
        "Respuesta_Referencia_Ground_Truth": "Sí. Este trastorno de la conducta alimentaria se denomina 'pica' y está estrechamente vinculado a la deficiencia severa de hierro (deficiencia ferropénica). El mecanismo exacto no está del todo claro, pero suele desaparecer por completo al corregir el déficit de hierro.",
        "Respuesta_sin_RAG": "Comer tierra o lamer paredes es una conducta normal de exploración lúdica en la infancia o denota la presencia de parásitos gigantes en el estómago, pero no guarda relación alguna con los niveles de minerales o hierro en el torrente sanguíneo."
    },
    {
        "ID": "Q053",
        "Categoria": "Diagnostico y Sintomas",
        "Pregunta": "Si un niño de 5 años tiene 9.5 de hemoglobina, ¿en qué nivel de anemia se encuentra?",
        "Respuesta_Referencia_Ground_Truth": "Para un niño de 5 años (60 meses a más), un valor de hemoglobina de 9.5 g/dL a nivel del mar se clasifica como Anemia Moderada (rango de 7.0 a 9.9 g/dL) según las tablas oficiales de clasificación del MINSA.",
        "Respuesta_sin_RAG": "Con 9.5 de hemoglobina a los 5 años, el paciente se encuentra en un estado de Anemia Severa o crítica, por lo que requiere hospitalización inmediata en cuidados intensivos para monitorización cardiovascular continua."
    },
    {
        "ID": "Q054",
        "Categoria": "Diagnostico y Sintomas",
        "Pregunta": "¿La anemia puede hacer que mi hijo no crezca bien o se quede chato?",
        "Respuesta_Referencia_Ground_Truth": "Sí. La deficiencia de hierro prolongada compromete la síntesis celular, disminuye la hormona de crecimiento y afecta el desarrollo muscular y esquelético del niño, lo que puede contribuir a retrasos en el crecimiento lineal y desnutrición crónica.",
        "Respuesta_sin_RAG": "No, la estatura está determinada al 100% por los genes de los padres. Ningún tipo de anemia o carencia nutricional temporal puede modificar la talla final del niño si genéticamente está destinado a ser alto."
    },
    {
        "ID": "Q055",
        "Categoria": "Diagnostico y Sintomas",
        "Pregunta": "¿Por qué mi bebé de 4 meses necesita un control si se le ve muy sanito y cachetón?",
        "Respuesta_Referencia_Ground_Truth": "Porque a partir de los 4 meses las reservas de hierro con las que nació el bebé empiezan a agotarse rápidamente debido a su acelerado crecimiento. El MINSA exige el control a esta edad para iniciar la suplementación preventiva con hierro en gotas antes de que desarrolle anemia.",
        "Respuesta_sin_RAG": "Es solo un control administrativo de rutina para actualizar su cartilla de vacunación. Si el bebé luce robusto, sonriente y de buen color, no corre ningún riesgo biológico y podrías saltarte esa cita médica sin problemas."
    },
    {
        "ID": "Q056",
        "Categoria": "Diagnostico y Sintomas",
        "Pregunta": "¿La anemia afecta el rendimiento y la inteligencia de los niños cuando entran al jardín?",
        "Respuesta_Referencia_Ground_Truth": "Sí, de forma irreversible si no se trata a tiempo. El hierro es vital para la mielinización de las neuronas y el desarrollo cognitivo durante los primeros mil días de vida. Su deficiencia disminuye la concentración, la memoria y el aprendizaje en la etapa escolar.",
        "Respuesta_sin_RAG": "No afecta la inteligencia del menor, solo produce flojera o somnolencia que se corrige fácilmente motivando al niño en clase o dándole suplementos energéticos azucarados antes de entrar al colegio."
    },
    {
        "ID": "Q057",
        "Categoria": "Diagnostico y Sintomas",
        "Pregunta": "Si la mamá tuvo anemia durante el embarazo, ¿el bebé nace automáticamente con anemia?",
        "Respuesta_Referencia_Ground_Truth": "No nace automáticamente con anemia, pero sí nace con reservas de hierro críticamente bajas. El feto extrae hierro de la madre, pero si esta sufre anemia severa, el bebé agotará sus escasos depósitos mucho antes de los 4 meses, desarrollando anemia de forma prematura.",
        "Respuesta_sin_RAG": "Sí, la anemia se transmite de forma hereditaria a través de la placenta durante la gestación. El bebé nacerá con los mismos niveles exactos de hemoglobina baja que tenía la madre al momento de dar a luz."
    },
    {
        "ID": "Q058",
        "Categoria": "Diagnostico y Sintomas",
        "Pregunta": "Mi hijo tiene dolores de cabeza seguidos y tiene 4 años, ¿puede ser por anemia?",
        "Respuesta_Referencia_Ground_Truth": "Sí. La disminución de glóbulos rojos aptos reduce la oxigenación en el sistema nervioso central, lo que genera fatiga celular e hipertensión compensatoria transitoria, manifestándose clínicamente como cefaleas (dolores de cabeza) e irritabilidad.",
        "Respuesta_sin_RAG": "En niños de 4 años los dolores de cabeza nunca son por anemia. Generalmente responden a problemas graves de miopía o astigmatismo que exigen el uso inmediato de lentes de medida, o a migrañas infantiles tensionales."
    },
    {
        "ID": "Q059",
        "Categoria": "Diagnostico y Sintomas",
        "Pregunta": "¿Un niño con sobrepeso u obesidad puede tener anemia o es imposible?",
        "Respuesta_Referencia_Ground_Truth": "Sí, es perfectamente posible. Esto se conoce como la 'paradoja de la malnutrición'. Un niño obeso puede consumir altas calorías en alimentos ultraprocesados pero carecer por completo de alimentos ricos en hierro, sumado a que la inflamación por obesidad bloquea la absorción del hierro.",
        "Respuesta_sin_RAG": "Es prácticamente imposible. Un niño con sobrepeso tiene abundantes reservas de nutrientes almacenadas en su tejido graso, lo que garantiza que sus niveles de hemoglobina y hierro sérico se mantengan siempre elevados."
    },
    {
        "ID": "Q060",
        "Categoria": "Diagnostico y Sintomas",
        "Pregunta": "¿Cómo sé si la anemia de mi hijo ya pasó de leve a moderada?",
        "Respuesta_Referencia_Ground_Truth": "La única forma objetiva y segura de saberlo es mediante un examen de control de laboratorio (hemoglobina). Clínicamente podrías notar mayor palidez, debilidad extrema o sueño excesivo, pero la sintomatología no reemplaza al valor cuantitativo del análisis de sangre.",
        "Respuesta_sin_RAG": "Lo sabrás de inmediato si el niño empieza a presentar fiebre alta por las noches, manchas moradas en la piel (petequias) o si se desmaya con frecuencia al realizar cualquier actividad física ligera en casa."
    },
    {
        "ID": "Q061",
        "Categoria": "Diagnostico y Sintomas",
        "Pregunta": "¿El tamizaje de anemia es gratuito en los centros de salud del MINSA para niños menores de 3 años?",
        "Respuesta_Referencia_Ground_Truth": "Sí. En el Perú, el diagnóstico, control y tratamiento de la anemia infantil es gratuito para todos los niños menores de 3 años en los establecimientos de salud pública del MINSA a través del Seguro Integral de Salud (SIS) y los programas de control de crecimiento.",
        "Respuesta_sin_RAG": "El examen es gratuito únicamente si el niño cuenta con una condición de desnutrición extrema calificada por una asistenta social, de lo contrario los padres deben abonar una tasa estándar por los reactivos de laboratorio."
    },
    {
        "ID": "Q062",
        "Categoria": "Diagnostico y Sintomas",
        "Pregunta": "¿Qué significa que los glóbulos rojos de mi hijo estén microcíticos e hipocrómicos en el análisis?",
        "Respuesta_Referencia_Ground_Truth": "Significa que los glóbulos rojos son más pequeños de lo normal (microcíticos) y tienen menos color o concentración de hemoglobina de lo debido (hipocrómicos). Esta es la característica laboratorial clásica de la anemia por deficiencia de hierro crónica.",
        "Respuesta_sin_RAG": "Es una alteración celular muy rara y peligrosa asociada a la leucemia infantil o fallas genéticas destructivas en la médula ósea que requiere la intervención urgente de un oncólogo pediatra."
    },
    {
        "ID": "Q063",
        "Categoria": "Diagnostico y Sintomas",
        "Pregunta": "A mi hijo le sudan mucho las manos y los pies y para frío, ¿es un síntoma de anemia pediátrica?",
        "Respuesta_Referencia_Ground_Truth": "Sí puede asociarse. Ante la escasez de hemoglobina, el cuerpo prioriza el flujo de sangre oxigenada hacia los órganos vitales (cerebro y corazón), disminuyendo la irrigación en las zonas periféricas, lo que causa frialdad en manos y pies, acompañado a veces de sudoración por estrés autonómico.",
        "Respuesta_sin_RAG": "La sudoración fría en las extremidades responde únicamente a problemas de hiperhidrosis emocional o problemas de tiroides (hipotiroidismo). No tiene ninguna relación con los glóbulos rojos o el hierro corporal."
    },
    {
        "ID": "Q064",
        "Categoria": "Diagnostico y Sintomas",
        "Pregunta": "Si mi hijo tiene 11.5 de hemoglobina a los 2 años, ¿está completamente libre de anemia?",
        "Respuesta_Referencia_Ground_Truth": "A nivel del mar, sí. Un valor de 11.5 g/dL se encuentra por encima del umbral mínimo de 11.0 g/dL exigido por el MINSA para niños de 24 meses. No obstante, se debe mantener una dieta rica en hierro para evitar que sus depósitos internos bajen en el futuro.",
        "Respuesta_sin_RAG": "No, a los 2 años el mínimo saludable es de 13.0 g/dL. Con 11.5 el niño se encuentra técnicamente en la zona de pre-anemia latente y requiere empezar a tomar jarabes fortificados de inmediato."
    },
    {
        "ID": "Q065",
        "Categoria": "Diagnostico y Sintomas",
        "Pregunta": "¿La anemia infantil puede causar soplos en el corazón si no se cura a tiempo?",
        "Respuesta_Referencia_Ground_Truth": "Sí. Cuando la anemia es moderada o severa, el corazón se ve obligado a bombear sangre mucho más rápido (estado hiperdinámico) para compensar la falta de oxígeno en los tejidos. Este flujo acelerado genera una turbulencia sanguínea que se escucha clínicamente como un soplo funcional.",
        "Respuesta_sin_RAG": "No, los soplos cardíacos en los niños son siempre de nacimiento (congénitos) debido a malformaciones en las válvulas del corazón. Ninguna deficiencia nutricional o de hierro puede alterar la estructura o los ruidos cardíacos."
    },
{
        "ID": "Q066",
        "Categoria": "Tratamiento y Suplementacion",
        "Pregunta": "El doctor le recetó gotas de sulfato ferroso a mi bebé de 5 meses, ¿cómo se las debo dar?",
        "Respuesta_Referencia_Ground_Truth": "Para un lactante de 5 meses con peso adecuado que recibe suplementación preventiva (2 mg/kg/día), las gotas deben administrarse entre las comidas (1 hora antes o 2 horas después de la leche materna). Se puede acompañar con unas gotas de un cítrico (vitamina C) para mejorar su absorción.",
        "Respuesta_sin_RAG": "El sulfato ferroso usualmente se da mezclado directamente en el biberón de leche para amortiguar el sabor amargo que es muy fuerte. La dosis estándar para casi todos los niños de esa edad es de unas 3 a 5 gotas todas las mañanas."
    },
    {
        "ID": "Q067",
        "Categoria": "Tratamiento y Suplementacion",
        "Pregunta": "A mi hijo le da estreñimiento el jarabe de hierro, ¿puedo suspender el tratamiento por unos días?",
        "Respuesta_Referencia_Ground_Truth": "No se debe suspender el tratamiento. El estreñimiento es un efecto secundario común debido al hierro no absorbido. El MINSA recomienda manejarlo aumentando el consumo de agua (si es mayor de 6 meses) y frutas pastosas como papaya o granadilla, pero jamás interrumpiendo las dosis.",
        "Respuesta_sin_RAG": "Sí, si notas que el niño sufre para evacuar o se estriñe mucho, puedes suspender el jarabe por 3 o 4 días hasta que su digestión se normalice por completo y luego retomar la misma dosis interdiaria."
    },
    {
        "ID": "Q068",
        "Categoria": "Tratamiento y Suplementacion",
        "Pregunta": "¿Es normal que las deposiciones de mi bebé se vuelvan negras o verdes oscuras tomando hierro?",
        "Respuesta_Referencia_Ground_Truth": "Sí, es un efecto secundario completamente normal, benigno y frecuente. Ocurre por la eliminación del exceso de hierro que el intestino no absorbe. No es un signo de enfermedad ni motivo para suspender el tratamiento prescrito.",
        "Respuesta_sin_RAG": "El cambio de color a negro o verde oscuro en las heces indica que el hierro le está causando una leve infección o irritación intestinal severa. Lo mejor es cortar el medicamento de inmediato y acudir a emergencias."
    },
    {
        "ID": "Q069",
        "Categoria": "Tratamiento y Suplementacion",
        "Pregunta": "¿A qué hora del día es mejor darle el jarabe de hierro a un niño para que le haga mejor efecto?",
        "Respuesta_Referencia_Ground_Truth": "La mejor hora es entre las comidas principales, idealmente a media mañana o a media tarde, garantizando que hayan pasado al menos 1 hora antes o 2 horas después de cualquier consumo de alimentos, especialmente lácteos, para evitar interferencias.",
        "Respuesta_sin_RAG": "Es mucho mejor dárselo justo antes de dormir por las noches. De esta manera, el cuerpo absorbe los minerales lentamente durante las horas de sueño profundo y evitas que el niño sienta náuseas durante el día."
    },
    {
        "ID": "Q070",
        "Categoria": "Tratamiento y Suplementacion",
        "Pregunta": "¿El sulfato ferroso se debe dar en ayunas o junto con el desayuno del niño?",
        "Respuesta_Referencia_Ground_Truth": "Se prefiere administrarlo alejado de los alimentos. Si se da junto con el desayuno, los fitatos de los cereales o el calcio de la leche bloquearán su absorción. Solo si produce demasiada irritación gástrica se podría dar con una fruta cítrica, pero no con el desayuno completo.",
        "Respuesta_sin_RAG": "Se recomienda encarecidamente darlo junto con un desayuno abundante que incluya avena o leche. Esto ayuda a crear una capa protectora en el estómago del menor, evitando que el ácido del sulfato ferroso le provoque gastritis crónicas."
    },
    {
        "ID": "Q071",
        "Categoria": "Tratamiento y Suplementacion",
        "Pregunta": "Mi hijo vomitó el jarabe de hierro apenas se lo di, ¿le tengo que volver a dar la dosis completa?",
        "Respuesta_Referencia_Ground_Truth": "Si el vómito ocurre inmediatamente (dentro de los primeros 15 minutos) y se expulsa todo el medicamento visible, el protocolo sugiere esperar a que el niño se calme e intentar administrar nuevamente la dosis completa. Si pasa más tiempo, ya no se repite.",
        "Respuesta_sin_RAG": "No, nunca se debe repetir la dosis si el niño vomita, ya que el revestimiento de su estómago queda muy sensible e inflamado. Espera hasta el día siguiente para darle su dosis normal y evitar una sobredosis accidental."
    },
    {
        "ID": "Q072",
        "Categoria": "Tratamiento y Suplementacion",
        "Pregunta": "¿El hierro en gotas o jarabe le puede manchar los dientes a mi hijo de 1 año? ¿Cómo lo evito?",
        "Respuesta_Referencia_Ground_Truth": "Sí, el hierro líquido puede causar una tinción oscura temporal en el esmalte dental al reaccionar con las bacterias de la boca. Se evita colocando las gotas en la parte posterior de la boca (usando gotero o jeringa) y realizando un cepillado dental con agua inmediatamente después.",
        "Respuesta_sin_RAG": "Las manchas oscuras en los dientes son permanentes porque el sulfato ferroso carcome el esmalte de los dientes de leche. No se puede evitar con limpieza, por lo que se sugiere cambiar a suplementos masticables comerciales."
    },
    {
        "ID": "Q073",
        "Categoria": "Tratamiento y Suplementacion",
        "Pregunta": "¿Cuál es la diferencia entre el sulfato ferroso y el hierro polimaltosado para los niños?",
        "Respuesta_Referencia_Ground_Truth": "El sulfato ferroso es una sal mineral tradicional con excelente absorción pero con mayor frecuencia de efectos secundarios digestivos (náuseas, estreñimiento). El hierro polimaltosado es un complejo estable que se absorbe de forma más lenta, genera menos malestar gástrico y no se altera tanto con los alimentos.",
        "Respuesta_sin_RAG": "El sulfato ferroso es un medicamento químico de baja calidad que da el Estado, mientras que el hierro polimaltosado es un tipo de hierro natural orgánico de origen vegetal que cura la anemia en la mitad de tiempo sin manchar los dientes."
    },
    {
        "ID": "Q074",
        "Categoria": "Tratamiento y Suplementacion",
        "Pregunta": "El centro de salud me dio unos sobrecitos de micronutrientes en polvo, ¿como se mezclan en la comida?",
        "Respuesta_Referencia_Ground_Truth": "Se debe separar una porción pequeña de solo 2 cucharadas de la comida principal (que sea una consistencia pastosa o puré, tibia o fría). Se vierte el contenido completo del sobre, se mezcla bien y se le da al niño primero; luego se continúa con el resto de su plato.",
        "Respuesta_sin_RAG": "Debes disolver todo el contenido del sobre en una taza grande con caldos calientes, sopas o jugos de frutas cítricas azucaradas. Es indispensable removerlo vigorosamente para que el polvo no se asiente al fondo del vaso."
    },
    {
        "ID": "Q075",
        "Categoria": "Tratamiento y Suplementacion",
        "Pregunta": "Si mi hijo ya subió su hemoglobina a 11.2, ¿debo dejar de darle el jarabe o tengo que seguir?",
        "Respuesta_Referencia_Ground_Truth": "Debe continuar obligatoriamente. Aunque la hemoglobina alcance niveles normales (mayor a 11.0 g/dL), el tratamiento según el MINSA debe completarse por 6 meses seguidos para rellenar los depósitos y reservas de hierro del cuerpo (ferritina) y evitar que vuelva a caer.",
        "Respuesta_sin_RAG": "Una vez que el análisis sale mayor a 11.0, el niño está oficialmente curado. Puedes suspender el tratamiento de inmediato de forma segura para no saturar su organismo con químicos innecesarios que estriñen al menor."
    },
    {
        "ID": "Q076",
        "Categoria": "Tratamiento y Suplementacion",
        "Pregunta": "¿Por cuántos meses seguidos debe tomar hierro un niño para curarse por completo de la anemia?",
        "Respuesta_Referencia_Ground_Truth": "El protocolo del MINSA determina que el tratamiento terapéutico para un niño con diagnóstico de anemia debe durar un periodo continuo de 6 meses seguidos, asegurando la normalización hematológica y el llenado de los almacenes orgánicos de hierro.",
        "Respuesta_sin_RAG": "Normalmente toma entre 15 días y un mes como máximo para que los glóbulos rojos se regeneren por completo. Extender el uso de hierro por más de dos meses consecutivos es peligroso y puede dañar el tejido renal."
    },
    {
        "ID": "Q077",
        "Categoria": "Tratamiento y Suplementacion",
        "Pregunta": "¿Qué pasa si me olvido de darle la dosis de hierro a mi hijo por dos días seguidos?",
        "Respuesta_Referencia_Ground_Truth": "Se retrasa la efectividad del tratamiento, pero no debes alarmarte ni duplicar la dosis al tercer día. Simplemente retoma la dosis diaria prescrita por el médico de inmediato y continúa con el conteo regular de los meses de tratamiento.",
        "Respuesta_sin_RAG": "Si olvidas dos días de dosis, el tratamiento pierde validez científica total y debes reiniciar el conteo de los 6 meses desde el día uno. Para compensar el olvido, dale el doble de mililitros durante los siguientes dos días."
    },
    {
        "ID": "Q078",
        "Categoria": "Tratamiento y Suplementacion",
        "Pregunta": "¿Se le puede mezclar el jarabe de hierro con la leche de su biberón para que no sienta el feo sabor?",
        "Respuesta_Referencia_Ground_Truth": "No. El calcio y las proteínas lácteas (como la caseína) forman complejos insolubles con el hierro en el estómago, bloqueando e inhibiendo casi por completo su absorción. El hierro nunca debe mezclarse con leche ni derivados lácteos.",
        "Respuesta_sin_RAG": "Sí, mezclarlo en el biberón de leche es la técnica pediátrica más recomendada en el hogar. La grasa de la leche recubre las moléculas de hierro, disminuyendo el sabor metálico y haciendo que el lactante lo reciba con agrado."
    },
    {
        "ID": "Q079",
        "Categoria": "Tratamiento y Suplementacion",
        "Pregunta": "Mi hijo de 3 años pesa 14 kilos y tiene anemia leve, ¿cuánto jarabe de sulfato ferroso le corresponde tomar?",
        "Respuesta_Referencia_Ground_Truth": "La dosis terapéutica es de 3 mg de hierro elemental por kilogramo de peso al día. Para un cálculo exacto y seguro de los mililitros diarios basándose en la concentración del jarabe provisto (sea 15 mg/5ml o 25 mg/5ml), el personal de salud del MINSA debe realizar la prescripción precisa en la cartilla.",
        "Respuesta_sin_RAG": "Para un niño de 3 años con ese peso corporal, le corresponde de manera fija tomar una cucharada sopera completa (lo que equivale a 15 ml) del jarabe dos veces al día, preferiblemente antes de cada comida fuerte."
    },
    {
        "ID": "Q080",
        "Categoria": "Tratamiento y Suplementacion",
        "Pregunta": "Le puedo dar el suplemento de hierro junto con su medicina para la fiebre o el jarabe para la tos?",
        "Respuesta_Referencia_Ground_Truth": "Se recomienda espaciar los medicamentos. El paracetamol o los jarabes para la tos no tienen una interacción química directa destructiva, pero administrar todo junto puede sobrecargar el estómago del niño, provocando náuseas o vómitos. Se sugiere separar las tomas por al menos 1 hora.",
        "Respuesta_sin_RAG": "No hay ningún inconveniente, puedes juntar el suplemento de hierro líquido con cualquier jarabe de antibióticos, antigripales o analgésicos en la misma cuchara para acelerar el proceso de administración de medicamentos."
    },
    {
        "ID": "Q081",
        "Categoria": "Tratamiento y Suplementacion",
        "Pregunta": "¿El hierro polimaltosado causa menos dolor de estómago o náuseas que el sulfato ferroso?",
        "Respuesta_Referencia_Ground_Truth": "Sí. Al estar el hierro envuelto en una matriz de carbohidratos (polimaltosa), no se liberan iones de hierro libres de forma masiva en el estómago. Esto reduce significativamente la irritación de la mucosa gástrica, disminuyendo las náuseas, vómitos y dolores abdominales.",
        "Respuesta_sin_RAG": "No, ambos compuestos químicos provocan exactamente la misma cantidad de dolores, aguras y gastritis. La única diferencia real en la práctica clínica es el costo comercial elevado que tiene el hierro polimaltosado en farmacias privadas."
    },
    {
        "ID": "Q082",
        "Categoria": "Tratamiento y Suplementacion",
        "Pregunta": "¿Qué alimentos cortan el efecto o la absorción del jarabe de hierro si se dan juntos?",
        "Respuesta_Referencia_Ground_Truth": "Los inhibidores principales son la leche, el yogur, el queso (por el calcio), las infusiones como manzanilla o anís, el té, el café, las gaseosas y los alimentos con exceso de fibra o fitatos (como salvado de trigo integral) si se consumen al mismo tiempo.",
        "Respuesta_sin_RAG": "Los únicos alimentos que cortan el efecto son los cítricos fuertes como el maracuyá, la piña y el kiwi debido a que sus ácidos degradan el compuesto activo del hierro en el estómago impidiendo que sirva para la hemoglobina."
    },
    {
        "ID": "Q083",
        "Categoria": "Tratamiento y Suplementacion",
        "Pregunta": "¿Puedo darle jugo de naranja a mi hijo inmediatamente después de que tome sus gotas de hierro?",
        "Respuesta_Referencia_Ground_Truth": "Sí, es una práctica altamente recomendada. La vitamina C (ácido ascórbico) del jugo de naranja optimiza la absorción intestinal del hierro, manteniendo el mineral en un estado soluble (ferroso) que el cuerpo asimila con mayor facilidad.",
        "Respuesta_sin_RAG": "No, debes esperar al menos dos horas. Combinar el hierro metálico con el ácido cítrico puro de la naranja provoca una reacción química efervescente en el estómago que destruye las vellosidades digestivas del niño."
    },
    {
        "ID": "Q084",
        "Categoria": "Tratamiento y Suplementacion",
        "Pregunta": "Mi bebé tiene 4 meses y nació a término con buen peso, ¿cuántas gotas de hierro de forma preventiva le tocan?",
        "Respuesta_Referencia_Ground_Truth": "Según el MINSA, le corresponde una dosis de prevención de 2 mg de hierro elemental por kilo de peso al día. La cantidad exacta de gotas diarias debe ser calculada y registrada en el establecimiento de salud según el peso exacto que registre el bebé en su control de los 4 meses.",
        "Respuesta_sin_RAG": "De manera estándar internacional y automatizada, a todos los bebés de 4 meses nacidos con buen peso les corresponde tomar un total de 20 gotas exactas de sulfato ferroso por la mañana antes de lactar."
    },
    {
        "ID": "Q085",
        "Categoria": "Tratamiento y Suplementacion",
        "Pregunta": "Si un niño toma una dosis muy alta de sulfato ferroso por error, ¿se puede intoxicar? ¿Qué debo hacer?",
        "Respuesta_Referencia_Ground_Truth": "Sí, la sobredosis de hierro es altamente tóxica y potencialmente mortal en niños (causa daño hepático y shock). Debes acudir inmediatamente al servicio de emergencias del hospital más cercano llevando el frasco del medicamento para la evaluación y aplicación de quelantes.",
        "Respuesta_sin_RAG": "No causa intoxicación porque el exceso de hierro se elimina de forma natural por la orina sin dejar secuelas. Si toma de más por accidente, solo dale abundante agua para limpiar sus riñones y suspende la dosis por un día."
    },
    {
        "ID": "Q086",
        "Categoria": "Tratamiento y Suplementacion",
        "Pregunta": "¿Las chispitas o micronutrientes causan diarrea o malestar estomacal en los bebés de 6 meses?",
        "Respuesta_Referencia_Ground_Truth": "En un porcentaje bajo de niños pueden provocar cambios transitorios en la consistencia de las deposiciones o un leve malestar. El MINSA aconseja no suspenderlos; por lo general, el sistema digestivo del bebé se adapta por completo en una o dos semanas.",
        "Respuesta_sin_RAG": "Sí, los micronutrientes en polvo destruyen la flora bacteriana de los bebés de 6 meses provocando cuadros de diarreas crónicas que conllevan a la deshidratación. Si ves que le suelta el estómago, debes botar los sobres."
    },
    {
        "ID": "Q087",
        "Categoria": "Tratamiento y Suplementacion",
        "Pregunta": "El doctor me dijo que le dé 2 mg por kilo de peso al bebé, ¿cómo calculo cuántas gotas son en total?",
        "Respuesta_Referencia_Ground_Truth": "El cálculo depende estrictamente de la marca o la presentación del sulfato ferroso que te entreguen, ya que la equivalencia de miligramos por gota varía (por ejemplo, en el MINSA una gota suele equivaler a 1.25 mg de hierro elemental). El cálculo exacto debe ser realizado y explicado por el enfermero o médico.",
        "Respuesta_sin_RAG": "Es una regla de tres simple fija en pediatría: multiplicas el peso del bebé por dos y el resultado numérico es el número de gotas exactas que debes succionar con el gotero plástico para darle en su boca."
    },
    {
        "ID": "Q088",
        "Categoria": "Tratamiento y Suplementacion",
        "Pregunta": "¿Se le puede dar el suplemento de hierro a un niño si está con un cuadro de diarrea o infección?",
        "Respuesta_Referencia_Ground_Truth": "Si el niño presenta un cuadro agudo de diarrea severa o fiebre alta por proceso infeccioso activo, el MINSA o el pediatra suelen recomendar suspender temporalmente la suplementación de hierro por unos días hasta que remita el cuadro agudo, ya que el hierro puede alimentar ciertas bacterias intestinales.",
        "Respuesta_sin_RAG": "Sí, debes continuar dándoselo con mayor rigurosidad porque durante las infecciones el cuerpo pierde glóbulos rojos el doble de rápido. El hierro ayuda a fortalecer el sistema de defensa directamente durante la fiebre."
    },
    {
        "ID": "Q089",
        "Categoria": "Tratamiento y Suplementacion",
        "Pregunta": "¿Por qué el tratamiento para la anemia en el MINSA dura hasta 6 meses si la hemoglobina sube en un mes?",
        "Respuesta_Referencia_Ground_Truth": "Porque en el primer o segundo mes el hierro consumido se usa para fabricar nuevos glóbulos rojos circulantes en la sangre. Los meses restantes (del tercero al sexto) son indispensables para almacenar el hierro en los depósitos de reserva del cuerpo (hígado y médula ósea) bajo la forma de ferritina.",
        "Respuesta_sin_RAG": "Es un protocolo burocrático de salud pública preventiva diseñado para asegurar que las madres sigan asistiendo a los controles de peso y talla mensuales en los consultorios, mas no por una necesidad biológica real del infante."
    },
    {
        "ID": "Q090",
        "Categoria": "Tratamiento y Suplementacion",
        "Pregunta": "¿Es malo comprarle vitaminas comerciales con hierro en la farmacia en lugar del sulfato ferroso del MINSA?",
        "Respuesta_Referencia_Ground_Truth": "No es malo en sí, pero muchas vitaminas comerciales contienen dosis de hierro elemental extremadamente bajas, insuficientes para tratar la anemia, además de incluir múltiples vitaminas innecesarias para este cuadro. Lo importante es garantizar la dosis miligramos/kilo exacta recetada.",
        "Respuesta_sin_RAG": "Sí, es perjudicial. Las vitaminas que se venden en cadenas de farmacias privadas contienen excipientes sintéticos que bloquean las células hematológicas, siendo mucho menos seguras que los jarabes estatales."
    },
    {
        "ID": "Q091",
        "Categoria": "Tratamiento y Suplementacion",
        "Pregunta": "A mi hijo le da muchas náuseas el olor del sulfato ferroso, ¿con qué fruta permitida se lo puedo camuflar?",
        "Respuesta_Referencia_Ground_Truth": "Se puede camuflar mezclando la dosis con una o dos cucharadas de papilla de granadilla, manzana o pera cocida, o dándole inmediatamente después un sorbo de jugo de naranja. Evita camuflarlo en grandes cantidades de comida para asegurar que tome la dosis completa.",
        "Respuesta_sin_RAG": "Lo ideal para camuflar el fuerte olor es licuar las gotas de hierro dentro de un vaso con leche de soya espesa o mezclarlo con chocolate líquido derretido caliente, lo cual neutraliza completamente el olor y sabor metálico."
    },
    {
        "ID": "Q092",
        "Categoria": "Tratamiento y Suplementacion",
        "Pregunta": "¿Qué pasa si le doy las gotas de hierro a mi bebé justo después de que tomó su teta?",
        "Respuesta_Referencia_Ground_Truth": "El calcio y las proteínas presentes en la leche materna reducirán la absorción del hierro en el intestino del lactante. Por ello, se debe respetar estrictamente el intervalo de tiempo de mínimo dos horas después de lactar para garantizar la absorción óptima.",
        "Respuesta_sin_RAG": "No pasa absolutamente nada, es un excelente hábito. La leche materna en el estómago ayuda a diluir el hierro de forma inmediata, facilitando que el mineral sea captado por la sangre sin causar gases gástricos."
    },
    {
        "ID": "Q093",
        "Categoria": "Tratamiento y Suplementacion",
        "Pregunta": "¿El tratamiento para la anemia moderada utiliza la misma dosis que para la anemia leve en niños?",
        "Respuesta_Referencia_Ground_Truth": "Sí. El esquema de tratamiento terapéutico general estipulado por el MINSA para niños con anemia ferropénica (sea leve o moderada) maneja la misma base de cálculo: 3 mg de hierro elemental por kilogramo de peso al día por un periodo de 6 meses.",
        "Respuesta_sin_RAG": "No, las dosis varían críticamente. Para la anemia moderada se duplica la cantidad de mililitros diarios e incluye inyecciones intramusculares semanales de complejo B para forzar al cuerpo a subir la hemoglobina en pocos días."
    },
    {
        "ID": "Q094",
        "Categoria": "Tratamiento y Suplementacion",
        "Pregunta": "Mi hijo tiene 2 años, ¿es mejor el hierro en gotas o ya debe pasar a tomar jarabe?",
        "Respuesta_Referencia_Ground_Truth": "A los 2 años, debido al peso corporal del niño, el volumen de gotas necesario para cubrir la dosis terapéutica es muy alto y difícil de administrar. Por ello, el MINSA recomienda realizar la transición al uso de jarabe, cuya concentración permite dar volúmenes menores en mililitros.",
        "Respuesta_sin_RAG": "A los 2 años es obligatorio suspender las gotas y el jarabe para pasar exclusivamente a pastillas trituradas o gomitas masticables comerciales, ya que los suplementos líquidos a esa edad causan rechazo psicológico."
    },
    {
        "ID": "Q095",
        "Categoria": "Tratamiento y Suplementacion",
        "Pregunta": "¿Los micronutrientes en polvo se pueden guardar si el niño no se terminó toda la comida del plato?",
        "Respuesta_Referencia_Ground_Truth": "No. Una vez abierto el sobre y mezclado con las dos primeras cucharadas de comida, debe ser consumido inmediatamente. Si el niño rechaza la comida, esa porción debe desecharse; no se puede guardar para el almuerzo o cena porque el hierro se oxida y cambia de sabor.",
        "Respuesta_sin_RAG": "Sí, puedes refrigerar la comida mezclada en un recipiente de plástico tapado hasta por 48 horas. Al momento de volver a dárselo, solo debes recalentarlo en el microondas para que los micronutrientes vuelvan a activarse."
    },
    {
        "ID": "Q096",
        "Categoria": "Tratamiento y Suplementacion",
        "Pregunta": "¿El agua pura ayuda a quitar el mal sabor de la boca después de tomar el sulfato ferroso?",
        "Respuesta_Referencia_Ground_Truth": "Ayuda a limpiar físicamente la cavidad bucal, pero el sabor metálico persistente se debe a la interacción de los iones de hierro con las papilas gustativas. Para mitigarlo de forma más eficaz, se prefiere dar un sorbo corto de un jugo cítrico permitido.",
        "Respuesta_sin_RAG": "El agua pura está prohibida inmediatamente después de tomar hierro ya que disuelve el medicamento en la saliva haciendo que se inactive antes de llegar al estómago. Es mejor dar un trozo de pan o galleta salada."
    },
    {
        "ID": "Q097",
        "Categoria": "Tratamiento y Suplementacion",
        "Pregunta": "¿Cuánto tiempo después de comer carne o sangrecita absorbe el cuerpo el hierro antes de poder darle leche?",
        "Respuesta_Referencia_Ground_Truth": "El proceso de digestión gástrica y absorción duodenal toma tiempo. El MINSA aconseja esperar un lapso mínimo de 2 horas después de haber consumido alimentos ricos en hierro antes de ofrecer cualquier producto lácteo (leche, yogur, queso).",
        "Respuesta_sin_RAG": "La absorción del hierro de las carnes es instantánea y ocurre en la boca por la saliva. Una vez que el niño traga el último pedazo de sangrecita, puedes darle su vaso de leche de inmediato sin ningún riesgo de bloqueo."
    },
    {
        "ID": "Q098",
        "Categoria": "Tratamiento y Suplementacion",
        "Pregunta": "¿El tratamiento de la anemia infantil varía si el niño sufre crónicamente de las amígdalas o alergias?",
        "Respuesta_Referencia_Ground_Truth": "El esquema de dosificación base de hierro por kilo se mantiene igual. No obstante, los procesos inflamatorios crónicos (como amigdalitis recurrentes) liberan hepcidina, una hormona que reduce la absorción del hierro oral. El médico debe vigilar de cerca la evolución del niño.",
        "Respuesta_sin_RAG": "Sí, en niños con alergias respiratorias o amígdalas grandes se suspende el hierro por completo debido a que el sulfato ferroso incrementa los niveles de histamina en el cuerpo empeorando los cuadros asmáticos crónicos."
    },
    {
        "ID": "Q099",
        "Categoria": "Tratamiento y Suplementacion",
        "Pregunta": "Si el niño no mejora su hemoglobina después de 3 meses con jarabe, ¿qué paso sigue en el protocolo médico?",
        "Respuesta_Referencia_Ground_Truth": "Si no hay respuesta al tratamiento tras 3 meses (falla terapéutica), el protocolo del MINSA exige evaluar la adherencia (si la madre realmente le da el hierro), descartar parasitosis intestinal, pérdidas de sangre ocultas o derivar al pediatra/hematólogo para investigar otras causas de anemia.",
        "Respuesta_sin_RAG": "El siguiente paso automático según el protocolo nacional es programar al menor para transfusiones de sangre directas en el hospital de la jurisdicción o cambiar el tratamiento oral por ampollas endovenosas de hierro hospitalario."
    },
    {
        "ID": "Q100",
        "Categoria": "Tratamiento y Suplementacion",
        "Pregunta": "¿La suplementación preventiva con hierro evita al 100% que a mi hijo le dé anemia antes del año de vida?",
        "Respuesta_Referencia_Ground_Truth": "No al 100%. La suplementación disminuye de forma drástica el riesgo de anemia ferropénica, pero la efectividad real depende del cumplimiento diario de la dosis, de un adecuado inicio de la alimentación complementaria rica en hierro a los 6 meses y de la ausencia de infecciones concurrentes.",
        "Respuesta_sin_RAG": "Sí, cumplir con las gotas preventivas a los 4 y 5 meses otorga un blindaje biológico absoluto e infalible, garantizando que el niño jamás desarrollará anemia durante toda su etapa de primera infancia sin importar lo que coma."
    }
    ]

nombre_archivo = "dataset_anemia_100.csv"

# 2. Escritura de los datos en el archivo CSV
with open(nombre_archivo, mode='w', newline='', encoding='utf-8') as archivo_csv:
    columnas = ["ID", "Categoria", "Pregunta", "Respuesta_Referencia_Ground_Truth", "Respuesta_sin_RAG", "Respuesta_con_RAG"]
    escritor = csv.DictWriter(archivo_csv, fieldnames=columnas)

    # Escribir cabecera
    escritor.writeheader()

    # Escribir cada fila asegurando que existan todas las columnas
    for p in dataset_prevencion_y_nutricion :
        # Aseguramos que la columna del RAG esté presente pero vacía para el experimento
        if "Respuesta_con_RAG" not in p:
            p["Respuesta_con_RAG"] = ""

        escritor.writerow(p)

print(f"Archivo '{nombre_archivo}' generado exitosamente con las {len(dataset_prevencion_y_nutricion )} filas y todas sus columnas.")
# Out:
# Archivo 'dataset_anemia_100.csv' generado exitosamente con las 100 filas y todas sus columnas.
